# %%
#Develop a basic crawler for the web search for user defined keywords.

# %%
pip install requests bs4

# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup

logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

class Crawler:

    def __init__(self, urls=[]):
        self.visited_urls = []
        self.urls_to_visit = urls

    def download_url(self, url):
        return requests.get(url).text

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path

    def add_url_to_visit(self, url):
        if url not in self.visited_urls and url not in self.urls_to_visit:
            self.urls_to_visit.append(url)

    def crawl(self, url):
        html = self.download_url(url)
        for url in self.get_linked_urls(url, html):
            self.add_url_to_visit(url)

    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)

if __name__ == '__main__':
    Crawler(urls=['https://www.mcdonalds.com/us/en-us.html']).run()
# Out:
# 2022-07-10 16:02:26,290 INFO:Crawling: https://www.mcdonalds.com/us/en-us.html
# 2022-07-10 16:02:26,926 INFO:Crawling: #maincontent
# 2022-07-10 16:02:26,928 ERROR:Failed to crawl: #maincontent
# Traceback (most recent call last):
#   File "<ipython-input-1-110dfcb41d28>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-1-110dfcb41d28>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-1-110dfcb41d28>", line 17, in download_url
#     return requests.get(url).text
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\sessions.py", line 519, in request
#     prep = self.prepare_request(req)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\sessions.py", line 462, in prepare_request
#     hooks=merge_hooks(request.hooks, self.hooks),
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\models.py", line 313, in prepare
#     self.prepare_url(url, params)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\models.py", line 387, in prepare_url
#     raise MissingSchema(error)
# requests.exceptions.MissingSchema: Invalid URL '#maincontent': No schema supplied. Perhaps you meant http://#maincontent?
# 2022-07-10 16:02:26,932 INFO:Crawling: https://www.mcdonalds.com/us/en-us.html
# 2022-07-10 16:02:27,440 INFO:Crawling:
# 2022-07-10 16:02:27,441 ERROR:Failed to crawl:
# Traceback (most recent call last):
#   File "<ipython-input-1-110dfcb41d28>", line 41, in run
#     self.crawl(url)
#   File "<ipython-input-1-110dfcb41d28>", line 32, in crawl
#     html = self.download_url(url)
#   File "<ipython-input-1-110dfcb41d28>", line 17, in download_url
#     return requests.get(url).text
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\api.py", line 75, in get
#     return request('get', url, params=params, **kwargs)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\api.py", line 60, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\sessions.py", line 519, in request
#     prep = self.prepare_request(req)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\sessions.py", line 462, in prepare_request
#     hooks=merge_hooks(request.hooks, self.hooks),
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\models.py", line 313, in prepare
#     self.prepare_url(url, params)
#   File "C:\Users\sanjay\Anaconda3\lib\site-packages\requests\models.py", line 387, in prepare_url
#     raise MissingSchema(error)
# requests.exceptions.MissingSchema: Invalid URL '': No schema supplied. Perhaps you meant http://?
# 2022-07-10 16:02:27,443 INFO:Crawling: https://www.mcdonalds.com/us/es-us.html
# 2022-07-10 16:02:27,929 INFO:Crawling: https://www.mcdonalds.com/us/en-us/mcdonalds-email-signup.html
# 2022-07-10 16:02:28,489 INFO:Crawling: https://www.mcdonalds.com/us/en-us/mcdonalds-careers.html
# 2022-07-10 16:02:29,096 INFO:Crawling: https://www.mcdonalds.com/us/en-us/full-men
# 2022-07-10 16:02:57,805 INFO:Crawling: https://www.mcdonalds.com/us/en-us/services/free-wi-fi.html
# 2022-07-10 16:02:58,398 INFO:Crawling: https://www.mcdonalds.com/us/en-us/services/arch-card.html
# 2022-07-10 16:02:59,030 INFO:Crawling: https://www.mcdonalds.com/us/en-us/services/playplaces-and-parties.html
# 2022-07-10 16:02:59,774 INFO:Crawling: https://www.mcdonalds.com/us/en-us/mobile-order-and-pay.html
# 2022-07-10 16:03:00,446 INFO:Crawling: https://www.mcdonalds.com/us/en-us/whats-hot.html
# 2022-07-10 16:03:01,200 INFO:Crawling: https://goldenarchesunlimited.com/
# 2022-07-10 16:03:02,269 INFO:Crawling: https://www.mcdonalds.com/us/en-us/family-fun-hub.html
# 2022-07-10 16:03:03,072 INFO:Crawling: https://www.mcdonalds.com/us/en-us/mccafe.html
# 2022-07-10 16:03:03,728 INFO:Crawling: https://www.mcdonalds.com/us/en-us/community.html
# 2022-07-10 16:03:04,438 INFO:Crawling: https://www.mcdonalds.com/us/en-us/community/hacer.html
# 2022-07-10 16:03:05,182 INFO:Crawling: https://www.mcdonalds.com/us/en-us/community/giving-back-with-ronald-mcdonald-house.html
# 2022-07-10 16:03:05,902 INFO:Crawling: https://www.mcdonalds.com/us/en-us/asian-pacific-americans/en.html
# 2022-07-10 16:03:06,584 INFO:Crawling: https://corporate.mcdonalds.com/corpmcd.html
# 2022-07-10 16:03:07,211 INFO:Crawling: https://www.mcdonalds.com/us/en-us/black-and-positively-golden.html
# 2022-07-10 16:03:07,932 INFO:Crawling: https://www.mcdonalds.com/us/en-us/community/lgbtq-plus.html
# 2022-07-10 16:03:08,691 INFO:Crawling: https://www.mcdonalds.com/us/en-us/contact-us.html
# 2022-07-10 16:03:09,977 INFO:Crawling: https://www.mcdonalds.com/us/en-us/faq/arch-card.html
# 2022-07-10 16:03:10,683 INFO:Crawling: https://www.mcdonalds.com/us/en-us/faq/business.html#donation
# 2022-07-10 16:03:11,184 INFO:Crawling: https://www.mcdonalds.com/us/en-us/faq/employment.html
# 2022-07-10 16:03:11,765 INFO:Crawling: https://www.mcdonalds.com/us/en-us/contact-us/restaurant-feedback.html
# 2022-07-10 16:03:12,273 INFO:Crawling: https://www.mcdonalds.com/us/en-us/faq.html
# 2022-07-10 16:03:12,859 INFO:Crawling: https://www.facebook.com/McDonalds/
# 2022-07-10 16:03:13,833 INFO:Crawling: https://twitter.com/mcdonalds
# 2022-07-10 16:03:14,815 INFO:Crawling: https://www.youtube.com/channel/UCRI5ZedBs0_BYY4PlxD6m7w
# 2022-07-10 16:03:15,501 INFO:Crawling: https://www.instagram.com/mcdonalds/
# 2022-07-10 16:03:17,003 INFO:Crawling: https://mcdonalds.tumblr.com/
# 2022-07-10 16:03:18,658 INFO:Crawling: https://open.spotify.com/user/mcdonalds
# 2022-07-10 16:03:19,311 INFO:Crawling: https://itunes.apple.com/us/app/mcdonalds-mobile/id922103212?mt=8
# 2022-07-10 16:03:25,422 INFO:Crawling: https://play.google.com/store/apps/details?id=com.mcdonalds.app&hl=en
# 2022-07-10 16:03:26,297 INFO:Crawling: https://www.mcdonalds.com/us/en-us/privacy-overview.html
# 2022-07-10 16:03:26,992 INFO:Crawling: https://www.mcdonalds.com/us/en-us/privacy.html#California-notice
